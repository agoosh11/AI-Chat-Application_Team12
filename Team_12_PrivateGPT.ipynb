# %%
# !git clone https://github.com/Tolulade-A/privateGPT.git
# Out:
# Cloning into 'privateGPT'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 57 (delta 24), reused 17 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 16.65 MiB | 9.37 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# !pip install -r /content/privateGPT/requirements.txt
# Out:
# Collecting langchain==0.0.274 (from -r /content/privateGPT/requirements.txt (line 1))
#   Downloading langchain-0.0.274-py3-none-any.whl.metadata (14 kB)
# Collecting gpt4all==1.0.8 (from -r /content/privateGPT/requirements.txt (line 2))
#   Downloading gpt4all-1.0.8-py3-none-manylinux1_x86_64.whl.metadata (912 bytes)
# Collecting chromadb==0.4.7 (from -r /content/privateGPT/requirements.txt (line 3))
#   Downloading chromadb-0.4.7-py3-none-any.whl.metadata (6.9 kB)
# Collecting llama-cpp-python==0.1.81 (from -r /content/privateGPT/requirements.txt (line 4))
#   Downloading llama_cpp_python-0.1.81.tar.gz (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting urllib3==2.0.4 (from -r /content/privateGPT/requirements.txt (line 5))
#   Downloading urllib3-2.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting PyMuPDF==1.23.1 (from -r /content/privateGPT/requirements.txt (line 6))
#   Downloading PyMuPDF-1.23.1-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting python-dotenv==1.0.0 (from -r /content/privateGPT/requirements.txt (line 7))
#   Downloading python_dotenv-1.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting unstructured==0.10.8 (from -r /content/privateGPT/requirements.txt (line 8))
#   Downloading unstructured-0.10.8-py3-none-any.whl.metadata (22 kB)
# Collecting extract-msg==0.45.0 (from -r /content/privateGPT/requirements.txt (line 9))
#   Downloading extract_msg-0.45.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tabulate==0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/privateGPT/requirements.txt (line 10)) (0.9.0)
# Collecting pandoc==2.3 (from -r /content/privateGPT/requirements.txt (line 11))
#   Downloading pandoc-2.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pypandoc==1.11 (from -r /content/privateGPT/requirements.txt (line 12))
#   Downloading pypandoc-1.11-py3-none-any.whl.metadata (16 kB)
# Collecting tqdm==4.66.1 (from -r /content/privateGPT/requirements.txt (line 13))
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.7 MB/s eta 0:00:00
# Collecting sentence_transformers==2.2.2 (from -r /content/privateGPT/requirements.txt (line 14))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting langsmith<0.1.0,>=0.0.21 (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading langsmith-0.0.92-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (2.32.3)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting pydantic<3,>=1 (from langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading pydantic-1.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.2/152.2 kB 11.9 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.2 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading chroma-hnswlib-0.7.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading fastapi-0.99.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (4.12.2)
# Collecting pulsar-client>=3.1.0 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading pulsar_client-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (6.4.5)
# Collecting bcrypt>=4.0.1 (from chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Collecting diskcache>=5.6.1 (from llama-cpp-python==0.1.81->-r /content/privateGPT/requirements.txt (line 4))
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting PyMuPDFb==1.23.0 (from PyMuPDF==1.23.1->-r /content/privateGPT/requirements.txt (line 6))
#   Downloading PyMuPDFb-1.23.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8)) (5.2.0)
# Collecting filetype (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8)) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8)) (4.12.3)
# Collecting emoji (from unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8))
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting imapclient<3,>=2.3.0 (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading IMAPClient-2.3.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting olefile==0.46 (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tzlocal<6,>=4.2 in /usr/local/lib/python3.10/dist-packages (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9)) (5.2)
# Collecting compressed-rtf<2,>=1.0.6 (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ebcdic<2,>=1.1.1 (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting RTFDE<0.2,>=0.1.0 (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading RTFDE-0.1.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting red-black-tree-mod==1.20 (from extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading red-black-tree-mod-1.20.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plumbum (from pandoc==2.3->-r /content/privateGPT/requirements.txt (line 11))
#   Downloading plumbum-1.8.3-py3-none-any.whl.metadata (10 kB)
# Collecting ply (from pandoc==2.3->-r /content/privateGPT/requirements.txt (line 11))
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (4.44.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (2.4.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (0.19.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (1.13.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (0.24.7)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8)) (2.6)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imapclient<3,>=2.3.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9)) (1.16.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (1.13.2)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pulsar-client>=3.1.0->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (3.8)
# Collecting lark~=1.1.8 (from RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading lark-1.1.9-py3-none-any.whl.metadata (1.9 kB)
# Collecting oletools>=0.56 (from RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading oletools-0.60.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (0.4.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (8.1.7)
# Collecting h11>=0.8 (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured==0.10.8->-r /content/privateGPT/requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (9.4.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9)) (3.1.4)
# Collecting easygui (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading easygui-0.98.3-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting colorclass (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pcodedmp>=1.2.5 (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading pcodedmp-1.2.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting msoffcrypto-tool (from oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9))
#   Downloading msoffcrypto_tool-5.4.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (3.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.274->-r /content/privateGPT/requirements.txt (line 1))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers==2.2.2->-r /content/privateGPT/requirements.txt (line 14)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.7->-r /content/privateGPT/requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: cryptography>=39.0 in /usr/local/lib/python3.10/dist-packages (from msoffcrypto-tool->oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9)) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=39.0->msoffcrypto-tool->oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=39.0->msoffcrypto-tool->oletools>=0.56->RTFDE<0.2,>=0.1.0->extract-msg==0.45.0->-r /content/privateGPT/requirements.txt (line 9)) (2.22)
# Downloading langchain-0.0.274-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.7 MB/s eta 0:00:00
# Downloading gpt4all-1.0.8-py3-none-manylinux1_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 84.4 MB/s eta 0:00:00
# Downloading chromadb-0.4.7-py3-none-any.whl (415 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 415.5/415.5 kB 24.7 MB/s eta 0:00:00
# Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 7.9 MB/s eta 0:00:00
# Downloading PyMuPDF-1.23.1-cp310-none-manylinux2014_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 76.4 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Downloading unstructured-0.10.8-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 58.9 MB/s eta 0:00:00
# Downloading extract_msg-0.45.0-py2.py3-none-any.whl (303 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.4/303.4 kB 20.2 MB/s eta 0:00:00
# Downloading pypandoc-1.11-py3-none-any.whl (20 kB)
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 6.0 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.23.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 63.2 MB/s eta 0:00:00
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 19.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.3 MB/s eta 0:00:00
# Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 9.8 MB/s eta 0:00:00
# Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.5 MB/s eta 0:00:00
# Downloading IMAPClient-2.3.1-py2.py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 14.1 MB/s eta 0:00:00
# Downloading langsmith-0.0.92-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 85.4 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.6.6-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 3.9 MB/s eta 0:00:00
# Downloading pulsar_client-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 93.1 MB/s eta 0:00:00
# Downloading pydantic-1.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 81.7 MB/s eta 0:00:00
# Downloading RTFDE-0.1.2-py3-none-any.whl (36 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.2 MB/s eta 0:00:00
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 25.3 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading plumbum-1.8.3-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.6/127.6 kB 9.5 MB/s eta 0:00:00
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.2 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 22.7 MB/s eta 0:00:00
# Downloading lark-1.1.9-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 8.3 MB/s eta 0:00:00
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.1 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading oletools-0.60.2-py2.py3-none-any.whl (989 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.4/989.4 kB 42.8 MB/s eta 0:00:00
# Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 4.4 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.1 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 25.9 MB/s eta 0:00:00
# Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 11.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pcodedmp-1.2.6-py2.py3-none-any.whl (30 kB)
# Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Downloading easygui-0.98.3-py2.py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 6.9 MB/s eta 0:00:00
# Downloading msoffcrypto_tool-5.4.2-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 3.1 MB/s eta 0:00:00
# Building wheels for collected packages: llama-cpp-python, pandoc, sentence_transformers, chroma-hnswlib, olefile, red-black-tree-mod, compressed-rtf, pypika
#   Building wheel for llama-cpp-python (pyproject.toml) ... done
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.1.81-cp310-cp310-linux_x86_64.whl size=411873 sha256=1b3cf8224e95b3688ad486a67ed837431c95504b05f5ffd946ff9f6b403840b5
#   Stored in directory: /root/.cache/pip/wheels/99/27/c0/ccda486d8dc16ebb8c61d9d7959380eced2cb3279cf0145dfe
#   Building wheel for pandoc (setup.py) ... done
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33261 sha256=40c03f6f062b9e18db13528c0faebeae54fa5487615b87c7e12e76ad7c7a194d
#   Stored in directory: /root/.cache/pip/wheels/76/27/c2/c26175310aadcb8741b77657a1bb49c50cc7d4cdbf9eee0005
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=3c286c0f0ca87ce419b9b039b94f5900016943b98ef3495e178f03f0e1af2310
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.2-cp310-cp310-linux_x86_64.whl size=2376586 sha256=a5f0971d4e5f1161e855bbc182114b2f594ea43550f7119b9e87281904061c9c
#   Stored in directory: /root/.cache/pip/wheels/11/2b/0d/ee457f6782f75315bb5828d5c2dc5639d471afbd44a830b9dc
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35418 sha256=49590a2610ed3bd7c050b9db889f565d68da1a649908728ebc270e7e63005cb6
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
#   Building wheel for red-black-tree-mod (setup.py) ... done
#   Created wheel for red-black-tree-mod: filename=red_black_tree_mod-1.20-py3-none-any.whl size=18623 sha256=dc7406b372bf462a11d5a09c7a9a06ad67e94d1fdaddade9c21388fd1550375e
#   Stored in directory: /root/.cache/pip/wheels/1e/89/a0/17d08e78a59e4e8f51a95fe52e19c6916450c143acc7bce4dd
#   Building wheel for compressed-rtf (setup.py) ... done
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6184 sha256=036f34d57dd63b9e5ab7a8b6e044e4a9b4726971cc7d5ee12b15a7ad0762d966
#   Stored in directory: /root/.cache/pip/wheels/15/3e/48/e7d833ecc516c36f8966d310b1a6386db091a718f1ff3bf85c
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=c7e96911960f85dbecedcb7ec6feb58e9a23e74b80114369ec3e8c89e63d9263
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built llama-cpp-python pandoc sentence_transformers chroma-hnswlib olefile red-black-tree-mod compressed-rtf pypika
# Installing collected packages: red-black-tree-mod, pypika, ply, monotonic, filetype, ebcdic, easygui, compressed-rtf, websockets, uvloop, urllib3, tqdm, tenacity, python-magic, python-dotenv, pypandoc, PyMuPDFb, pydantic, pulsar-client, plumbum, overrides, olefile, mypy-extensions, marshmallow, lark, imapclient, humanfriendly, httptools, h11, emoji, diskcache, colorclass, chroma-hnswlib, bcrypt, backoff, watchfiles, uvicorn, typing-inspect, starlette, PyMuPDF, pandoc, llama-cpp-python, coloredlogs, unstructured, posthog, onnxruntime, msoffcrypto-tool, langsmith, gpt4all, fastapi, dataclasses-json, langchain, chromadb, sentence_transformers, pcodedmp, oletools, RTFDE, extract-msg
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.1
#     Uninstalling pydantic-2.9.1:
#       Successfully uninstalled pydantic-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.15 requires pydantic>=2.7.0, but you have pydantic 1.10.18 which is incompatible.
# Successfully installed PyMuPDF-1.23.1 PyMuPDFb-1.23.0 RTFDE-0.1.2 backoff-2.2.1 bcrypt-4.2.0 chroma-hnswlib-0.7.2 chromadb-0.4.7 colorclass-2.2.2 coloredlogs-15.0.1 compressed-rtf-1.0.6 dataclasses-json-0.5.14 diskcache-5.6.3 easygui-0.98.3 ebcdic-1.1.1 emoji-2.12.1 extract-msg-0.45.0 fastapi-0.99.1 filetype-1.2.0 gpt4all-1.0.8 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 imapclient-2.3.1 langchain-0.0.274 langsmith-0.0.92 lark-1.1.9 llama-cpp-python-0.1.81 marshmallow-3.22.0 monotonic-1.6 msoffcrypto-tool-5.4.2 mypy-extensions-1.0.0 olefile-0.46 oletools-0.60.2 onnxruntime-1.19.2 overrides-7.7.0 pandoc-2.3 pcodedmp-1.2.6 plumbum-1.8.3 ply-3.11 posthog-3.6.6 pulsar-client-3.5.0 pydantic-1.10.18 pypandoc-1.11 pypika-0.48.9 python-dotenv-1.0.0 python-magic-0.4.27 red-black-tree-mod-1.20 sentence_transformers-2.2.2 starlette-0.27.0 tenacity-8.5.0 tqdm-4.66.1 typing-inspect-0.9.0 unstructured-0.10.8 urllib3-2.0.4 uvicorn-0.30.6 uvloop-0.20.0 watchfiles-0.24.0 websockets-13.0.1

# %%
# !wget https://gpt4all.io/models/ggml-gpt4all-j-v1.3-groovy.bin
# Out:
# --2024-09-17 19:26:14--  https://gpt4all.io/models/ggml-gpt4all-j-v1.3-groovy.bin
# Resolving gpt4all.io (gpt4all.io)... 104.26.1.159, 172.67.71.169, 104.26.0.159, ...
# Connecting to gpt4all.io (gpt4all.io)|104.26.1.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3785248281 (3.5G)
# Saving to: ‘ggml-gpt4all-j-v1.3-groovy.bin’
#
# ggml-gpt4all-j-v1.3 100%[===================>]   3.52G  32.0MB/s    in 78s
#
# 2024-09-17 19:27:33 (46.1 MB/s) - ‘ggml-gpt4all-j-v1.3-groovy.bin’ saved [3785248281/3785248281]

# %%
import os
os.rename('/content/privateGPT/example.env', '.env')

# %%
# !ls -a
# Out:
# .  ..  .config	.env  ggml-gpt4all-j-v1.3-groovy.bin  privateGPT  sample_data

# %%
# !cat .env
# Out:
# PERSIST_DIRECTORY=/content/db
# MODEL_TYPE=GPT4All
# MODEL_PATH=/content/ggml-gpt4all-j-v1.3-groovy.bin
# EMBEDDINGS_MODEL_NAME=all-MiniLM-L6-v2
# MODEL_N_CTX=1000
# MODEL_N_BATCH=8
# TARGET_SOURCE_CHUNKS=4

# %%
# !python /content/privateGPT/ingest.py
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'cached_download' (from 'huggingface_hub.file_download') is deprecated and will be removed from version '0.26'. Use `hf_hub_download` instead.
#   warnings.warn(warning_message, FutureWarning)
# .gitattributes: 100% 1.23k/1.23k [00:00<00:00, 5.07MB/s]
# 1_Pooling/config.json: 100% 190/190 [00:00<00:00, 760kB/s]
# README.md: 100% 10.7k/10.7k [00:00<00:00, 32.8MB/s]
# config.json: 100% 612/612 [00:00<00:00, 2.79MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 567kB/s]
# data_config.json: 100% 39.3k/39.3k [00:00<00:00, 2.72MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:00<00:00, 152MB/s]
# model.onnx: 100% 90.4M/90.4M [00:02<00:00, 35.7MB/s]
# pytorch_model.bin: 100% 90.9M/90.9M [00:01<00:00, 73.7MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 263kB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 603kB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 12.6MB/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.12MB/s]
# train_script.py: 100% 13.2k/13.2k [00:00<00:00, 38.3MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 7.94MB/s]
# modules.json: 100% 349/349 [00:00<00:00, 1.85MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Creating new vectorstore
# Loading documents from /content/privateGPT/source_documents
# Loading new documents: 100%|██████████████████████| 4/4 [00:03<00:00,  1.27it/s]
# Loaded 1099 new documents from /content/privateGPT/source_documents
# Split into 5618 chunks of text (max. 500 tokens each)
# Creating embeddings. May take some minutes...
# Ingestion complete! You can now run privateGPT.py to query your documents

# %%
# !python /content/privateGPT/privateGPT.py
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Found model file at  /content/ggml-gpt4all-j-v1.3-groovy.bin
# gptj_model_load: loading model from '/content/ggml-gpt4all-j-v1.3-groovy.bin' - please wait ...
# gptj_model_load: n_vocab = 50400
# gptj_model_load: n_ctx   = 2048
# gptj_model_load: n_embd  = 4096
# gptj_model_load: n_head  = 16
# gptj_model_load: n_layer = 28
# gptj_model_load: n_rot   = 64
# gptj_model_load: f16     = 2
# gptj_model_load: ggml ctx size = 5401.45 MB
# gptj_model_load: kv self size  =  896.00 MB
# gptj_model_load: ................................... done
# gptj_model_load: model size =  3609.38 MB / num tensors = 285
#
# Enter a query: What is the state of the Union?
#  The United States of America (USA)
#
# > Question:
# What is the state of the Union?
#
# > Answer (took 1468.4 s.):
#  The United States of America (USA)
#
# > /content/privateGPT/source_documents/Essentials-of-Business-Analytics (1).pdf:
# Political Economy, 81(3), 637–654.
#
# > /content/privateGPT/source_documents/Essentials-of-Business-Analytics (1).pdf:
# where |U| is the aggregated (in)efﬁciency.
# 4http://www.fao.org/docrep/006/Y5027E/y5027e0d.htm (accessed on Jul 6, 2018).
#
# > /content/privateGPT/source_documents/Essentials-of-Business-Analytics (1).pdf:
# is different from a standard state because of Las Vegas. New Hampshire does not
# impose sales tax. It does not impose income tax at state level. Thus these three states
# behave differently from other states with respect to cigarette consumption. So it is
# meaningful to consider regression after dropping these observations.
# The corresponding output is provided in Table 7.8.
#
# > /content/privateGPT/source_documents/Essentials-of-Business-Analytics (1).pdf:
# (“US_Dept_of_Commerce.csv”) to calculate the growth rate of per capita Gross
# State Product (GSP). We also control for the unemployment rate, obtained from
# the Bureau of Labor Statistics, and a number of state-speciﬁc, time-varying socio-
# demographic characteristics, including the percentage of high school dropouts, the
# proportion of blacks, and the proportion of female-headed households.
# Name
# Description
# Log_gini
# Logarithm of Gini index of income inequality
# Gsp_pc_growth
#
# Enter a query:
